# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/telecom_churn.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
print("Estos son las columnas: \n", df.columns, len(df.columns), sep="\n")
# Out:
# Estos son las columnas:
#
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')
# 20

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df["Churn"] = df["Churn"].astype("int64")

# %%
df["Churn"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
df.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df["Churn"].value_counts(normalize=True).plot(
    kind="bar", grid=True, colormap="coolwarm", title="Distribución de Churn"
)
# Out:
# <Axes: title={'center': 'Distribución de Churn'}, xlabel='Churn'>

# %%
df.sort_values(by="Total day charge", ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=["Total day charge", "Churn"], ascending=[True, False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0                0
# 1397                      0                0.0                0
# 2736                     27                2.6              113
# 2753                      0                7.8               86
# 1986                      0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df[df["Churn"] == 1]["Churn"].describe()
# Out:
# count    483.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: Churn, dtype: float64

# %%
df[(df["Churn"] == 0) & (df["International plan"] == "No")]["Total intl minutes"].max()
# Out:
# 18.9

# %%
df_1 = df[df["Churn"] == 0]
df_1
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
my_lista = ["Total day minutes", "Total eve minutes", "Total night minutes"]
my_lista[1:2]
# Out:
# ['Total eve minutes']

# %%
df.query("Churn == 0 & `International plan` == 'No'")
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.loc[0:5, "State":"Area code"]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[0:5, 0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
df[-2:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# ...

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
my_func = lambda x: x + 1
my_func(5)
# Out:
# 6

# %%
def func_1(x):
    return x + 1


func_1(1)
# Out:
# 2

# %%
df["State"].apply(lambda x: x[0] == "W").sum()
# Out:
# 327

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
d = {
    "valor_1": [1, 2, 3],
    "valor_2": [4, 5, 6],
    "valor_3": "Hola",
    "valor_4": {"valor_5": "Mundo", "valor_6": 5},
}

# %%
d["valor_4"]["valor_5"]
# Out:
# 'Mundo'

# %%
d = {"No": False, "Yes": True}
d
# Out:
# {'No': False, 'Yes': True}

# %%
df["International plan bool"] = df["International plan"].map(d)

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.replace({"Voice mail plan": d, "International plan": d})
# Out:
# /var/folders/gb/wf3d1d_d2bz689q8kdbw02880000gn/T/ipykernel_19112/2934152483.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Voice mail plan": d, "International plan": d})
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# ...

# %%
lista_columna = ["Voice mail plan", "International plan"]
type(lista_columna)
# Out:
# list

# %%
df.apply(lambda x: x.map(d))
# Out:
#      State Account length Area code  International plan  Voice mail plan  \
# 0      NaN            NaN       NaN               False             True
# 1      NaN            NaN       NaN               False             True
# 2      NaN            NaN       NaN               False            False
# 3      NaN            NaN       NaN                True            False
# 4      NaN            NaN       NaN                True            False
# ...    ...            ...       ...                 ...              ...
# 3328   NaN            NaN       NaN               False             True
# 3329   NaN            NaN       NaN               False            False
# 3330   NaN            NaN       NaN               False            False
# 3331   NaN            NaN       NaN                True            False
# 3332   NaN            NaN       NaN               False             True
#
#      Number vmail messages Total day minutes Total day calls Total day charge  \
# ...

# %%
def row(x):
    if x == "Yes":
        return True
    if x == "No":
        return False
    else:
        return x


df.applymap(row)
# Out:
# /var/folders/gb/wf3d1d_d2bz689q8kdbw02880000gn/T/ipykernel_19112/2156250138.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(row)
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 3328    AZ             192        415               False             True
# 3329    WV              68        415               False            False
# 3330    RI              28        510               False            False
# ...

# %%
columns_to_show = [
    "Total day minutes", 
    "Total eve minutes", 
    "Total night minutes"
    ]

# %%
df.groupby("Churn")[columns_to_show].describe().T
# Out:
# Churn                                0           1
# Total day minutes   count  2850.000000  483.000000
#                     mean    175.175754  206.914079
#                     std      50.181655   68.997792
#                     min       0.000000    0.000000
#                     25%     142.825000  153.250000
#                     50%     177.200000  217.600000
#                     75%     210.300000  265.950000
#                     max     315.600000  350.800000
# Total eve minutes   count  2850.000000  483.000000
#                     mean    199.043298  212.410145
#                     std      50.292175   51.728910
#                     min       0.000000   70.900000
#                     25%     164.500000  177.100000
#                     50%     199.600000  211.300000
#                     75%     233.200000  249.450000
#                     max     361.800000  363.700000
# Total night minutes count  2850.000000  483.000000
# ...

# %%
columns_to_show = [
    "Total day minutes", 
    "Total eve minutes", 
    "Total night minutes"
    ]

df.groupby("Churn")[columns_to_show].agg(
    [np.mean, np.std, np.min, max]
    ).T
# Out:
# /var/folders/gb/wf3d1d_d2bz689q8kdbw02880000gn/T/ipykernel_19112/767323473.py:7: FutureWarning: The provided callable <function mean at 0x10c05faf0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Churn")[columns_to_show].agg(
# /var/folders/gb/wf3d1d_d2bz689q8kdbw02880000gn/T/ipykernel_19112/767323473.py:7: FutureWarning: The provided callable <function std at 0x10c05fca0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby("Churn")[columns_to_show].agg(
# ...

# %%
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes", "State"]

df.groupby("Churn").agg(
    sum_total_minutes=pd.NamedAgg(
        column="Total day minutes", 
        aggfunc="sum"
        ),
    num_state_w = pd.NamedAgg(
        column="State",
        aggfunc=lambda x: x[x.str[0] == "W"].count()
        )
)
# Out:
#        sum_total_minutes  num_state_w
# Churn
# 0               499250.9          287
# 1                99939.5           40

# %%
datos_1 = pd.crosstab(
    df["Churn"], df["International plan"], normalize="columns", margins=True
)

datos_1
# Out:
# International plan       No       Yes       All
# Churn
# 0                   0.88505  0.575851  0.855086
# 1                   0.11495  0.424149  0.144914

# %%
df.pivot_table(
    values=[
        "Total day calls", 
        "Total eve calls", 
        "Total night calls"],
    index = ["Area code"],
    aggfunc="mean"
)
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
total_calls = df["Total day calls"] + df["Total eve calls"] + df["Total night calls"]

total_calls
# Out:
# 0       300
# 1       329
# 2       328
# 3       248
# 4       356
#        ...
# 3328    286
# 3329    235
# 3330    258
# 3331    326
# 3332    272
# Length: 3333, dtype: int64

# %%
df["total_calls"] = total_calls

# %%
df["total_calls"] = (
    df["Total day calls"] + df["Total eve calls"] + df["Total night calls"]
)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.to_csv("../data/my_coold_df.csv")

# %%
import os
os.getcwd()
# Out:
# '/Users/diegofernandezgil/learning/mlcourse.ai/mi_trabajo'
